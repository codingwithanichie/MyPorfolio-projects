# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r'C:\Users\ichie\Desktop\data work\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB
# None

# %%
df['budget'].fillna(0, inplace=True)
df['gross'].fillna(0, inplace=True)
df.replace([pd.NA, pd.NaT, float('inf'), -float('inf')], 0, inplace=True)

# %%
try:
    df['budget'] = df['budget'].astype('int64')
    df['gross'] = df['gross'].astype('int64')
except ValueError as e:
    print("Error:", e)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0   James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0   Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0   James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0     J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0   Anthony Russo
# ...                                 ...    ...        ...             ...
# 1617   January 26, 1990 (United States)    4.5      274.0     Andrew Lane
# 1614     April 14, 1989 (United States)    5.2     1300.0  Gérard Kikoïne
# 1606      April 7, 1989 (United States)    6.0     2900.0    Tibor Takács
# 1601           January 13, 1990 (Japan)    7.1     1500.0   Ildikó Enyedi
# 7667    August 19, 2020 (United States)    5.7        7.0    Pereko Mosia
#
#                   writer               star         country     budget  \
# 5445       James Cameron    Sam Worthington   United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.   United States  356000000
# 3045       James Cameron  Leonardo DiCaprio   United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley   United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.   United States  321000000
# ...                  ...                ...             ...        ...
# 1617      Alan Moskowitz      Zach Galligan   United States          0
# 1614          J.P. Félix    Anthony Perkins  United Kingdom          0
# 1606       David Chaskin       Jenny Wright          Canada          0
# 1601       Ildikó Enyedi       Dorota Segda         Hungary          0
# 7667        Pereko Mosia   Siyabonga Mabaso    South Africa          0
#
#            gross                          company  runtime  \
# 5445  2847246203            Twentieth Century Fox    162.0
# 7445  2797501328                   Marvel Studios    181.0
# 3045  2201647264            Twentieth Century Fox    194.0
# 6663  2069521700                        Lucasfilm    138.0
# 7244  2048359754                   Marvel Studios    149.0
# ...          ...                              ...      ...
# 1617           0          Gibraltar Entertainment     92.0
# 1614           0                    Allied Vision     85.0
# 1606           0  Trans World Entertainment (TWE)     89.0
# 1601           0         Budapest Stúdió Vállalat    104.0
# 7667           0                      PK 65 Films    102.0
#
#                         yearcorrect
# 5445  December 18, 2009 (United Sta
# 7445     April 26, 2019 (United Sta
# 3045  December 19, 1997 (United Sta
# 6663  December 18, 2015 (United Sta
# 7244     April 27, 2018 (United Sta
# ...                             ...
# 1617   January 26, 1990 (United Sta
# 1614     April 14, 1989 (United Sta
# 1606      April 7, 1989 (United Sta
# 1601           January 13, 1990 (Ja
# 7667    August 19, 2020 (United Sta
#
# [7668 rows x 16 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df['company'] = df['company'].astype(str).drop_duplicates().sort_values(ascending=False)

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1048       55  19000000   46998772     2320    146.0         1706
# 1   328       56   4500000   58853106      732    104.0         1493
# 2  1746       56  18000000  538375067     1541    124.0         1772
# 3  2247       56   3500000   83453539     1813     88.0         1493
# 4   411       56   6000000   39846344     1778     98.0         1544

# %%
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget VS Gross Earnings')

plt.xlabel('Gross Earning')
plt.ylabel('Budget For Film')
plt.show()

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
# C:\Users\ichie\AppData\Local\Temp\ipykernel_29384\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for numeric features')

plt.xlabel('Movie Features')
plt.ylabel('Movies Features')
plt.show()
# Out:
# C:\Users\ichie\AppData\Local\Temp\ipykernel_29384\3965926425.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1048       55  19000000   46998772     2320    146.0         1706
# 1   328       56   4500000   58853106      732    104.0         1493
# 2  1746       56  18000000  538375067     1541    124.0         1772
# 3  2247       56   3500000   83453539     1813     88.0         1493
# 4   411       56   6000000   39846344     1778     98.0         1544

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for numeric features')

plt.xlabel('Movie Features')
plt.ylabel('Movies Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# gross        0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186392
# company      0.000598 -0.018078  0.100808 -0.039350  0.029045  0.059211
# runtime      0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
# yearcorrect -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#                 votes  director    writer      star   country    budget  \
# name         0.013088  0.009079  0.009081  0.006472 -0.010737  0.020548
# rating       0.033225  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre       -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year         0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.309212
# released     0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.009145
# score        0.409182  0.009559  0.019416 -0.001609 -0.133348  0.055665
# votes        1.000000  0.000260  0.000892 -0.019282  0.073625  0.486862
# director     0.000260  1.000000  0.299067  0.039234  0.017490  0.004976
# writer       0.000892  0.299067  1.000000  0.027245  0.015343 -0.025911
# star        -0.019282  0.039234  0.027245  1.000000 -0.012998 -0.019952
# country      0.073625  0.017490  0.015343 -0.012998  1.000000  0.131720
# budget       0.486862  0.004976 -0.025911 -0.019952  0.131720  1.000000
# gross        0.632834 -0.014916 -0.022997 -0.001129  0.095325  0.750157
# company     -0.109861  0.005280  0.003107  0.024866 -0.149973 -0.201938
# runtime      0.309212  0.017624 -0.003511  0.010174 -0.078412  0.269510
# yearcorrect  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.009145
#
#                 gross   company   runtime  yearcorrect
# name         0.006989  0.000598  0.010392    -0.011311
# rating      -0.095450 -0.018078  0.062145     0.016613
# genre       -0.234297  0.100808 -0.052711     0.029822
# year         0.261900 -0.039350  0.120811    -0.000695
# released     0.000519  0.029045  0.000868     1.000000
# score        0.186392  0.059211  0.399451     0.042788
# votes        0.632834 -0.109861  0.309212     0.016097
# director    -0.014916  0.005280  0.017624    -0.001478
# writer      -0.022997  0.003107 -0.003511    -0.002404
# star        -0.001129  0.024866  0.010174     0.015777
# country      0.095325 -0.149973 -0.078412    -0.020427
# budget       0.750157 -0.201938  0.269510     0.009145
# gross        1.000000 -0.149691  0.245235     0.000519
# company     -0.149691  1.000000 -0.010848     0.029045
# runtime      0.245235 -0.010848  1.000000     0.000868
# yearcorrect  0.000519  0.029045  0.000868     1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.000598
#              runtime        0.010392
#              yearcorrect   -0.011311
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.081939
#              gross         -0.095450
#              company       -0.018078
#              runtime        0.062145
#              yearcorrect    0.016613
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027965
#              votes         -0.145307
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.334021
#              gross         -0.234297
#              company        0.100808
#              runtime       -0.052711
#              yearcorrect    0.029822
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.097995
#              votes          0.222945
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.309212
#              gross          0.261900
#              company       -0.039350
#              runtime        0.120811
#              yearcorrect   -0.000695
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.042788
#              votes          0.016097
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company        0.029045
#              runtime        0.000868
#              yearcorrect    1.000000
# score        name           0.017097
#              rating        -0.001314
#              genre          0.027965
#              year           0.097995
#              released       0.042788
#              score          1.000000
#              votes          0.409182
#              director       0.009559
#              writer         0.019416
#              star          -0.001609
#              country       -0.133348
#              budget         0.055665
#              gross          0.186392
#              company        0.059211
#              runtime        0.399451
#              yearcorrect    0.042788
# votes        name           0.013088
#              rating         0.033225
#              genre         -0.145307
#              year           0.222945
#              released       0.016097
#              score          0.409182
#              votes          1.000000
#              director       0.000260
#              writer         0.000892
#              star          -0.019282
#              country        0.073625
#              budget         0.486862
#              gross          0.632834
#              company       -0.109861
#              runtime        0.309212
#              yearcorrect    0.016097
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.009559
#              votes          0.000260
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget         0.004976
#              gross         -0.014916
#              company        0.005280
#              runtime        0.017624
#              yearcorrect   -0.001478
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.019416
#              votes          0.000892
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.025911
#              gross         -0.022997
#              company        0.003107
#              runtime       -0.003511
#              yearcorrect   -0.002404
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.001609
#              votes         -0.019282
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019952
#              gross         -0.001129
#              company        0.024866
#              runtime        0.010174
#              yearcorrect    0.015777
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133348
#              votes          0.073625
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.131720
#              gross          0.095325
#              company       -0.149973
#              runtime       -0.078412
#              yearcorrect   -0.020427
# budget       name           0.020548
#              rating        -0.081939
#              genre         -0.334021
#              year           0.309212
#              released       0.009145
#              score          0.055665
#              votes          0.486862
#              director       0.004976
#              writer        -0.025911
#              star          -0.019952
#              country        0.131720
#              budget         1.000000
#              gross          0.750157
#              company       -0.201938
#              runtime        0.269510
#              yearcorrect    0.009145
# gross        name           0.006989
#              rating        -0.095450
#              genre         -0.234297
#              year           0.261900
#              released       0.000519
#              score          0.186392
#              votes          0.632834
#              director      -0.014916
#              writer        -0.022997
#              star          -0.001129
#              country        0.095325
#              budget         0.750157
#              gross          1.000000
#              company       -0.149691
#              runtime        0.245235
#              yearcorrect    0.000519
# company      name           0.000598
#              rating        -0.018078
#              genre          0.100808
#              year          -0.039350
#              released       0.029045
#              score          0.059211
#              votes         -0.109861
#              director       0.005280
#              writer         0.003107
#              star           0.024866
#              country       -0.149973
#              budget        -0.201938
#              gross         -0.149691
#              company        1.000000
#              runtime       -0.010848
#              yearcorrect    0.029045
# runtime      name           0.010392
#              rating         0.062145
#              genre         -0.052711
#              year           0.120811
#              released       0.000868
#              score          0.399451
#              votes          0.309212
#              director       0.017624
#              writer        -0.003511
#              star           0.010174
#              country       -0.078412
#              budget         0.269510
#              gross          0.245235
#              company       -0.010848
#              runtime        1.000000
#              yearcorrect    0.000868
# yearcorrect  name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.042788
#              votes          0.016097
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company        0.029045
#              runtime        0.000868
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
# gross        genre         -0.234297
# genre        gross         -0.234297
# budget       company       -0.201938
# company      budget        -0.201938
# country      company       -0.149973
# company      country       -0.149973
# gross        company       -0.149691
# company      gross         -0.149691
# genre        votes         -0.145307
# votes        genre         -0.145307
# score        country       -0.133348
# country      score         -0.133348
# company      votes         -0.109861
# votes        company       -0.109861
# rating       gross         -0.095450
# gross        rating        -0.095450
# rating       budget        -0.081939
# budget       rating        -0.081939
# year         genre         -0.081261
# genre        year          -0.081261
# runtime      country       -0.078412
# country      runtime       -0.078412
# year         country       -0.070938
# country      year          -0.070938
# runtime      genre         -0.052711
# genre        runtime       -0.052711
# year         company       -0.039350
# company      year          -0.039350
# genre        country       -0.037615
# country      genre         -0.037615
# star         year          -0.027242
# year         star          -0.027242
# budget       writer        -0.025911
# writer       budget        -0.025911
# gross        writer        -0.022997
# writer       gross         -0.022997
# year         director      -0.020795
# director     year          -0.020795
# released     country       -0.020427
# country      released      -0.020427
#              yearcorrect   -0.020427
# yearcorrect  country       -0.020427
# star         budget        -0.019952
# budget       star          -0.019952
# star         votes         -0.019282
# votes        star          -0.019282
# rating       company       -0.018078
# company      rating        -0.018078
# genre        director      -0.015258
# director     genre         -0.015258
#              gross         -0.014916
# gross        director      -0.014916
# star         country       -0.012998
# country      star          -0.012998
# released     name          -0.011311
# name         released      -0.011311
# yearcorrect  name          -0.011311
# name         yearcorrect   -0.011311
# company      runtime       -0.010848
# runtime      company       -0.010848
# name         country       -0.010737
# country      name          -0.010737
# writer       year          -0.008656
# year         writer        -0.008656
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# genre        star          -0.005477
# star         genre         -0.005477
# runtime      writer        -0.003511
# writer       runtime       -0.003511
#              yearcorrect   -0.002404
# yearcorrect  writer        -0.002404
# writer       released      -0.002404
# released     writer        -0.002404
# star         score         -0.001609
# score        star          -0.001609
# director     yearcorrect   -0.001478
# yearcorrect  director      -0.001478
# released     director      -0.001478
# director     released      -0.001478
# rating       score         -0.001314
# score        rating        -0.001314
# star         gross         -0.001129
# gross        star          -0.001129
# yearcorrect  year          -0.000695
# released     year          -0.000695
# year         yearcorrect   -0.000695
#              released      -0.000695
# votes        director       0.000260
# director     votes          0.000260
# gross        yearcorrect    0.000519
# yearcorrect  gross          0.000519
# gross        released       0.000519
# released     gross          0.000519
# company      name           0.000598
# name         company        0.000598
# runtime      released       0.000868
# released     runtime        0.000868
# yearcorrect  runtime        0.000868
# runtime      yearcorrect    0.000868
# votes        writer         0.000892
# writer       votes          0.000892
#              company        0.003107
# company      writer         0.003107
# budget       director       0.004976
# director     budget         0.004976
# company      director       0.005280
# director     company        0.005280
# name         star           0.006472
# star         name           0.006472
# genre        writer         0.006567
# writer       genre          0.006567
# name         gross          0.006989
# gross        name           0.006989
# year         rating         0.008779
# rating       year           0.008779
# director     name           0.009079
# name         director       0.009079
#              writer         0.009081
# writer       name           0.009081
# yearcorrect  budget         0.009145
# budget       yearcorrect    0.009145
#              released       0.009145
# released     budget         0.009145
# score        director       0.009559
# director     score          0.009559
# runtime      star           0.010174
# star         runtime        0.010174
# name         runtime        0.010392
# runtime      name           0.010392
# year         name           0.011453
# name         year           0.011453
#              votes          0.013088
# votes        name           0.013088
# star         rating         0.013405
# rating       star           0.013405
# country      writer         0.015343
# writer       country        0.015343
# star         yearcorrect    0.015777
# yearcorrect  star           0.015777
# released     star           0.015777
# star         released       0.015777
# released     votes          0.016097
# votes        released       0.016097
# yearcorrect  votes          0.016097
# votes        yearcorrect    0.016097
# genre        name           0.016355
# name         genre          0.016355
# rating       released       0.016613
# yearcorrect  rating         0.016613
# rating       yearcorrect    0.016613
# released     rating         0.016613
# name         score          0.017097
# score        name           0.017097
# director     country        0.017490
# country      director       0.017490
# director     runtime        0.017624
# runtime      director       0.017624
# writer       score          0.019416
# score        writer         0.019416
# rating       director       0.019483
# director     rating         0.019483
# budget       name           0.020548
# name         budget         0.020548
# star         company        0.024866
# company      star           0.024866
# star         writer         0.027245
# writer       star           0.027245
# genre        score          0.027965
# score        genre          0.027965
# company      released       0.029045
# released     company        0.029045
# yearcorrect  company        0.029045
# company      yearcorrect    0.029045
# genre        released       0.029822
# yearcorrect  genre          0.029822
# released     genre          0.029822
# genre        yearcorrect    0.029822
# votes        rating         0.033225
# rating       votes          0.033225
# star         director       0.039234
# director     star           0.039234
# score        yearcorrect    0.042788
# released     score          0.042788
# score        released       0.042788
# yearcorrect  score          0.042788
# budget       score          0.055665
# score        budget         0.055665
# company      score          0.059211
# score        company        0.059211
# runtime      rating         0.062145
# rating       runtime        0.062145
# genre        rating         0.072423
# rating       genre          0.072423
# country      votes          0.073625
# votes        country        0.073625
# country      rating         0.081244
# rating       country        0.081244
# country      gross          0.095325
# gross        country        0.095325
# year         score          0.097995
# score        year           0.097995
# company      genre          0.100808
# genre        company        0.100808
# year         runtime        0.120811
# runtime      year           0.120811
# country      budget         0.131720
# budget       country        0.131720
# gross        score          0.186392
# score        gross          0.186392
# votes        year           0.222945
# year         votes          0.222945
# gross        runtime        0.245235
# runtime      gross          0.245235
# gross        year           0.261900
# year         gross          0.261900
# budget       runtime        0.269510
# runtime      budget         0.269510
# writer       director       0.299067
# director     writer         0.299067
# year         budget         0.309212
# budget       year           0.309212
# runtime      votes          0.309212
# votes        runtime        0.309212
# runtime      score          0.399451
# score        runtime        0.399451
#              votes          0.409182
# votes        score          0.409182
#              budget         0.486862
# budget       votes          0.486862
# gross        votes          0.632834
# votes        gross          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  released       1.000000
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     yearcorrect    1.000000
#              released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross        votes          0.632834
# votes        gross          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  released       1.000000
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     yearcorrect    1.000000
#              released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
